# %% [markdown]
# # Per-Department Retention Graphs
#
# <img src="ucla_ps_box.png" alt="UCLA Physical Sciences" width="200"/>
#
# Here are interactive graphs that show the retention rates for each department in UCLA's Division of Physical Sciences. They can be subdivided in Freshman vs Transfer admits and URM vs Non-URM students.
#
# All students were classified as either:
# 1. getting a degree in the department they were admitted to,
# 2. getting a degree in another department (either in the division or elsewhere), or
# 3. not getting a degree.
#
# URM rates are consistently worse than Non-URM rates. Transfer rates are consistently better than Freshman rates. Rates vary significantly between departments.
#
# #### Methodological Notes
# I split the double majors into both departments for accurate retention analysis. For example, if there were 5 aos/math majors, and they all graduated with aos/math degrees, all of those students would count toward the retention rates of both departments.
#
# The freshman in the 2021 cohort are the latest to have graduated. Most people in later cohorts have not graduated, contributing to extremely high "No Degree" rates.
#
# ---

# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# make csv
maj2dept = {
    'atmospheric and oceanic sciences': 'aos',
    'climate science': 'aos',
    'aos/math': 'aos',
    'biochemistry': 'chemistry and biochemistry',
    'chemistry': 'chemistry and biochemistry',
    'materials science': 'chemistry and biochemistry',
    'gen chem for teaching': 'chemistry and biochemistry',
    'geology': 'epss',
    'engineering geology': 'epss',
    'geophysics': 'epss',
    'earth and environmental science': 'epss',
    'mathematics': 'math',
    'applied mathematics': 'math',
    'financial actuarial mathematics': 'math',
    'mathematics/applied science': 'math',
    'mathematics of computation': 'math',
    'mathematics for teaching': 'math',
    'mathematics/economics': 'math',
    'astrophysics': 'physics and astronomy',
    'biophysics': 'physics and astronomy',
    'physics': 'physics and astronomy',
    'physics-ba': 'physics and astronomy',
    'statistics and data science': 'statistics',
    'data theory': 'statistics',
    'environmental science': 'institute of environment and sustainability',
}

dbl_majs = {
    'atmospheric and oceanic sciences/mathematics',
    'chemistry/materials science',
    'geography/environmental studies',
    'geology/engineering geology',
    'geology/paleobiology',
    'geophysics/applied geophysics',
    'geophysics/geophysics and space physics'
    'mathematics/applied science',
    'mathematics/economics'
    'design / media arts',
}

special_cases = {'no degree': 'no degree', 'undeclared': 'undeclared'} # make better name
maj2dept_and_friends = maj2dept | special_cases


df = pd.read_csv("raw_data.csv")

# Data cleaning
df.rename(columns={'cohort_major_desc': 'start_maj', 'deg_major_desc': 'end_maj', 'freshman_transfer': 'fresh'}, inplace=True)
for col in ['urm', 'fresh', 'start_maj', 'end_maj']:
    df[col] = df[col].str.strip().str.lower()
df['cohort'] = df['cohort'].str[:4].astype(int)
df['urm'] = df['urm'].map({'urm': True, 'non-urm': False})
df['fresh'] = df['fresh'].map({'freshman': True, 'transfer': False})
df['start_maj'] = df['start_maj'].replace('general chemistry', 'chemistry').replace('undeclared-physical science', 'undeclared')

# Track depts
df['start_dept'] = df['start_maj'].map(maj2dept_and_friends)

def temp_maj2dept_mapper_that_handles_other_divs(maj): # will be replaced by extending maj2dept to all divisions
    return maj2dept_and_friends.get(maj, 'other')

df['end_dept'] = df['end_maj'].map(temp_maj2dept_mapper_that_handles_other_divs)

def categorize_outcome(row):
    if row['end_dept'] == 'no degree':
        return 'no degree'
    if row['end_dept'] == row['start_dept']:
        return 'retained'
    else: # other dept in div, or other div
        return 'other degree'
    
df['outcome'] = df.apply(categorize_outcome, axis=1)

# %%
def expand_double_majors(df):
    """
    Expand rows with double majors (containing '/') into separate rows
    """
    expanded_rows = []
    
    for _, row in df.iterrows():
        start_majors = row['start_maj'].split('/') if '/' in str(row['start_maj']) else [row['start_maj']]
        end_majors = row['end_maj'].split('/') if '/' in str(row['end_maj']) and pd.notna(row['end_maj']) else [row['end_maj']]
        print(start_majors, end_majors)
        
        # Create a row for each combination
        for start_maj in start_majors:
            for end_maj in end_majors:
                new_row = row.copy()
                new_row['start_maj'] = start_maj.strip()
                new_row['end_maj'] = end_maj.strip() if pd.notna(end_maj) else end_maj
                expanded_rows.append(new_row)
    
    return pd.DataFrame(expanded_rows)

# Usage
df = expand_double_majors(df)
# Out:
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['art history']
# ['applied mathematics'] ['business economics']
# ['applied mathematics'] ['chemical engineering']
# ['applied mathematics'] ['economics']
# ['applied mathematics'] ['european languages and transcultural studies with french and francophone']
# ['applied mathematics'] ['geophysics', 'geophysics and space physics']
# ['applied mathematics'] ['international development studies']
# ['applied mathematics'] ['linguistics']
# ['applied mathematics'] ['mathematics of computation']
# ['applied mathematics'] ['mathematics', 'applied science']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['political science']
# ['applied mathematics'] ['psychology']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['applied mathematics']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['biophysics']
# ['astrophysics'] ['economics']
# ['astrophysics'] ['mathematics', 'economics']
# ['astrophysics'] ['music history']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['atmospheric and oceanic sciences', 'mathematics'] ['applied mathematics']
# ['biochemistry'] ['anthropology']
# ['biochemistry'] ['anthropology-bs']
# ['biochemistry'] ['art history']
# ['biochemistry'] ['asian american studies']
# ['biochemistry'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['bioengineering']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['biophysics']
# ['biochemistry'] ['business economics']
# ['biochemistry'] ['chemical engineering']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['computational and systems biology']
# ['biochemistry'] ['computer science']
# ['biochemistry'] ['ecology, behavior, and evolution']
# ['biochemistry'] ['economics']
# ['biochemistry'] ['electrical engineering']
# ['biochemistry'] ['english']
# ['biochemistry'] ['gender studies']
# ['biochemistry'] ['geography', 'environmental studies']
# ['biochemistry'] ['history']
# ['biochemistry'] ['human biology and society - bs']
# ['biochemistry'] ['international development studies']
# ['biochemistry'] ['korean']
# ['biochemistry'] ['microbiology, immunology, and molecular genetics']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['neuroscience']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['nursing-prelicensure']
# ['biochemistry'] ['physics']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['political science']
# ['biochemistry'] ['psychobiology']
# ['biochemistry'] ['psychology']
# ['biophysics'] ['applied mathematics']
# ['biophysics'] ['electrical engineering']
# ['biophysics'] ['environmental science']
# ['biophysics'] ['neuroscience']
# ['biophysics'] ['physiological science']
# ['biophysics'] ['political science']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['anthropology-bs']
# ['chemistry'] ['astrophysics']
# ['chemistry'] ['atmospheric and oceanic sciences']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['biology']
# ['chemistry'] ['biophysics']
# ['chemistry'] ['business economics']
# ['chemistry'] ['chemical engineering']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['chemistry', 'materials science']
# ['chemistry'] ['comparative literature']
# ['chemistry'] ['computer science']
# ['chemistry'] ['ecology, behavior, and evolution']
# ['chemistry'] ['economics']
# ['chemistry'] ['electrical engineering']
# ['chemistry'] ['english']
# ['chemistry'] ['environmental science']
# ['chemistry'] ['geography']
# ['chemistry'] ['linguistics']
# ['chemistry'] ['materials engineering']
# ['chemistry'] ['mechanical engineering']
# ['chemistry'] ['microbiology, immunology, and molecular genetics']
# ['chemistry'] ['molecular, cell, and developmental biology']
# ['chemistry'] ['neuroscience']
# ['chemistry'] ['no degree']
# ['chemistry'] ['physiological science']
# ['chemistry'] ['psychobiology']
# ['chemistry'] ['psychology']
# ['chemistry'] ['sociology']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['chemistry', 'materials science'] ['mathematics', 'applied science']
# ['earth and environmental science'] ['anthropology']
# ['earth and environmental science'] ['art history']
# ['earth and environmental science'] ['english']
# ['earth and environmental science'] ['geography']
# ['earth and environmental science'] ['political science']
# ['geology'] ['geology']
# ['geology', 'engineering geology'] ['no degree']
# ['geophysics', 'applied geophysics'] ['biophysics']
# ['geophysics', 'geophysics and space physics'] ['geophysics', 'applied geophysics']
# ['mathematics'] ['aerospace engineering']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['atmospheric and oceanic sciences']
# ['mathematics'] ['business economics']
# ['mathematics'] ['cognitive science']
# ['mathematics'] ['computer science and engineering']
# ['mathematics'] ['economics']
# ['mathematics'] ['electrical engineering']
# ['mathematics'] ['english']
# ['mathematics'] ['global studies']
# ['mathematics'] ['linguistics and computer science']
# ['mathematics'] ['linguistics and philosophy']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics for teaching']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'applied science']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['no degree']
# ['mathematics'] ['physics']
# ['mathematics'] ['psychology']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['biology']
# ['mathematics for teaching'] ['classical civilization']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['sociology']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['computer science']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics of computation'] ['mathematics', 'economics']
# ['mathematics of computation'] ['statistics and data science']
# ['mathematics', 'applied science'] ['aerospace engineering']
# ['mathematics', 'applied science'] ['anthropology-bs']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['biochemistry']
# ['mathematics', 'applied science'] ['biology']
# ['mathematics', 'applied science'] ['business economics']
# ['mathematics', 'applied science'] ['economics']
# ['mathematics', 'applied science'] ['electrical engineering']
# ['mathematics', 'applied science'] ['financial actuarial mathematics']
# ['mathematics', 'applied science'] ['history']
# ['mathematics', 'applied science'] ['international development studies']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['mathematics', 'economics']
# ['mathematics', 'applied science'] ['microbiology, immunology, and molecular genetics']
# ['mathematics', 'applied science'] ['neuroscience']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'applied science'] ['physiological science']
# ['mathematics', 'applied science'] ['psychobiology']
# ['mathematics', 'applied science'] ['psychology']
# ['mathematics', 'applied science'] ['statistics and data science']
# ['mathematics', 'economics'] ['american literature and culture']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['business economics']
# ['mathematics', 'economics'] ['economics']
# ['mathematics', 'economics'] ['mathematics']
# ['mathematics', 'economics'] ['mathematics', 'applied science']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['philosophy']
# ['mathematics', 'economics'] ['political science']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['applied mathematics']
# ['physics'] ['biophysics']
# ['physics'] ['business economics']
# ['physics'] ['earth and environmental science']
# ['physics'] ['economics']
# ['physics'] ['geophysics', 'applied geophysics']
# ['physics'] ['history']
# ['physics'] ['no degree']
# ['physics'] ['philosophy']
# ['physics'] ['physics']
# ['physics'] ['political science']
# ['physics'] ['psychobiology']
# ['statistics and data science'] ['art history']
# ['statistics and data science'] ['economics']
# ['statistics and data science'] ['mathematics', 'applied science']
# ['statistics and data science'] ['psychology']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['anthropology']
# ['undeclared'] ['applied mathematics']
# ['undeclared'] ['asian american studies']
# ['undeclared'] ['asian humanities']
# ['undeclared'] ['atmospheric and oceanic sciences']
# ['undeclared'] ['biochemistry']
# ['undeclared'] ['bioengineering']
# ['undeclared'] ['biology']
# ['undeclared'] ['biophysics']
# ['undeclared'] ['business economics']
# ['undeclared'] ['chemical engineering']
# ['undeclared'] ['chemistry']
# ['undeclared'] ['chemistry', 'materials science']
# ['undeclared'] ['civil engineering']
# ['undeclared'] ['communication']
# ['undeclared'] ['computer science']
# ['undeclared'] ['economics']
# ['undeclared'] ['electrical engineering']
# ['undeclared'] ['english']
# ['undeclared'] ['environmental science']
# ['undeclared'] ['film and television']
# ['undeclared'] ['geography']
# ['undeclared'] ['geology', 'engineering geology']
# ['undeclared'] ['history']
# ['undeclared'] ['international development studies']
# ['undeclared'] ['materials engineering']
# ['undeclared'] ['mathematics']
# ['undeclared'] ['mathematics', 'economics']
# ['undeclared'] ['microbiology, immunology, and molecular genetics']
# ['undeclared'] ['molecular, cell, and developmental biology']
# ['undeclared'] ['no degree']
# ['undeclared'] ['philosophy']
# ['undeclared'] ['physics']
# ['undeclared'] ['physiological science']
# ['undeclared'] ['political science']
# ['undeclared'] ['psychobiology']
# ['undeclared'] ['psychology']
# ['undeclared'] ['sociology']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['geography']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['physics']
# ['atmospheric and oceanic sciences', 'mathematics'] ['no degree']
# ['biochemistry'] ['applied mathematics']
# ['biochemistry'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['ecology, behavior, and evolution']
# ['biochemistry'] ['electrical engineering']
# ['biochemistry'] ['mathematics', 'applied science']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['statistics and data science']
# ['biophysics'] ['biophysics']
# ['chemistry'] ['arabic']
# ['chemistry'] ['asian american studies']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['biology']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['chemistry', 'materials science']
# ['chemistry'] ['general chemistry']
# ['chemistry'] ['geography']
# ['chemistry'] ['mathematics']
# ['chemistry'] ['mathematics', 'economics']
# ['chemistry'] ['microbiology, immunology, and molecular genetics']
# ['chemistry'] ['neuroscience']
# ['chemistry'] ['no degree']
# ['chemistry'] ['sociology']
# ['chemistry'] ['statistics and data science']
# ['chemistry', 'materials science'] ['chemistry']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['earth and environmental science'] ['atmospheric and oceanic sciences']
# ['earth and environmental science'] ['environmental science']
# ['geology'] ['geology']
# ['mathematics'] ['anthropology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['asian american studies']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics', 'applied science']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['philosophy']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['applied mathematics']
# ['mathematics for teaching'] ['history']
# ['mathematics for teaching'] ['mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['chemistry']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics', 'applied science'] ['anthropology']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['geography']
# ['mathematics', 'applied science'] ['geography', 'environmental studies']
# ['mathematics', 'applied science'] ['mathematics']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['mathematics', 'economics']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'applied science'] ['physics']
# ['mathematics', 'applied science'] ['statistics and data science']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['economics']
# ['mathematics', 'economics'] ['history']
# ['mathematics', 'economics'] ['mathematics']
# ['mathematics', 'economics'] ['mathematics', 'applied science']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['mathematics']
# ['physics'] ['mathematics', 'economics']
# ['physics'] ['microbiology, immunology, and molecular genetics']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['physics'] ['physics-ba']
# ['statistics and data science'] ['applied mathematics']
# ['statistics and data science'] ['asian studies']
# ['statistics and data science'] ['japanese']
# ['statistics and data science'] ['mathematics']
# ['statistics and data science'] ['mathematics', 'applied science']
# ['statistics and data science'] ['no degree']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['economics']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['asian american studies']
# ['applied mathematics'] ['chicana and chicano studies']
# ['applied mathematics'] ['economics']
# ['applied mathematics'] ['mathematics']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['philosophy']
# ['applied mathematics'] ['spanish']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['biochemistry']
# ['astrophysics'] ['geophysics', 'applied geophysics']
# ['astrophysics'] ['political science']
# ['astrophysics'] ['spanish']
# ['atmospheric and oceanic sciences'] ['environmental science']
# ['biochemistry'] ['anthropology']
# ['biochemistry'] ['anthropology-bs']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['comparative literature']
# ['biochemistry'] ['economics']
# ['biochemistry'] ['environmental science']
# ['biochemistry'] ['geography', 'environmental studies']
# ['biochemistry'] ['history']
# ['biochemistry'] ['international development studies']
# ['biochemistry'] ['neuroscience']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['philosophy']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['political science']
# ['biochemistry'] ['psychobiology']
# ['biochemistry'] ['psychology']
# ['biochemistry'] ['russian language and literature']
# ['biophysics'] ['biophysics']
# ['biophysics'] ['history']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['atmospheric and oceanic sciences']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['environmental science']
# ['chemistry'] ['history']
# ['chemistry'] ['linguistics']
# ['chemistry'] ['microbiology, immunology, and molecular genetics']
# ['chemistry'] ['molecular, cell, and developmental biology']
# ['chemistry'] ['neuroscience']
# ['chemistry'] ['political science']
# ['chemistry'] ['psychology']
# ['chemistry'] ['sociology']
# ['chemistry', 'materials science'] ['political science']
# ['earth and environmental science'] ['biology']
# ['earth and environmental science'] ['history']
# ['earth and environmental science'] ['microbiology, immunology, and molecular genetics']
# ['mathematics'] ['african american studies']
# ['mathematics'] ['anthropology']
# ['mathematics'] ['civil engineering']
# ['mathematics'] ['economics']
# ['mathematics'] ['english']
# ['mathematics'] ['environmental science']
# ['mathematics'] ['international development studies']
# ['mathematics'] ['sociology']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['chicana and chicano studies']
# ['mathematics for teaching'] ['history']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['no degree']
# ['mathematics for teaching'] ['political science']
# ['mathematics for teaching'] ['spanish']
# ['mathematics of computation'] ['chicana and chicano studies']
# ['mathematics of computation'] ['political science']
# ['mathematics', 'applied science'] ['anthropology']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['chemical engineering']
# ['mathematics', 'applied science'] ['chicana and chicano studies']
# ['mathematics', 'applied science'] ['cognitive science']
# ['mathematics', 'applied science'] ['earth and environmental science']
# ['mathematics', 'applied science'] ['international development studies']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['political science']
# ['mathematics', 'applied science'] ['sociology']
# ['mathematics', 'economics'] ['european languages and transcultural studies with french and francophone']
# ['mathematics', 'economics'] ['spanish']
# ['physics'] ['anthropology']
# ['physics'] ['art']
# ['physics'] ['geography']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['statistics and data science'] ['economics']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['anthropology']
# ['undeclared'] ['applied mathematics']
# ['undeclared'] ['atmospheric and oceanic sciences']
# ['undeclared'] ['ecology, behavior, and evolution']
# ['undeclared'] ['english']
# ['undeclared'] ['geography', 'environmental studies']
# ['undeclared'] ['history']
# ['undeclared'] ['human biology and society - ba']
# ['undeclared'] ['international development studies']
# ['undeclared'] ['no degree']
# ['undeclared'] ['political science']
# ['undeclared'] ['psychology']
# ['undeclared'] ['sociology']
# ['applied mathematics'] ['applied mathematics']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['geophysics', 'geophysics and space physics']
# ['astrophysics'] ['no degree']
# ['astrophysics'] ['physics']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['history']
# ['biophysics'] ['anthropology-bs']
# ['biophysics'] ['biophysics']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['anthropology-bs']
# ['chemistry'] ['biology']
# ['chemistry'] ['chemistry']
# ['geology'] ['earth and environmental science']
# ['geology'] ['geology']
# ['geology', 'engineering geology'] ['geology', 'engineering geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['chicana and chicano studies']
# ['mathematics'] ['geography']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['applied mathematics']
# ['mathematics for teaching'] ['no degree']
# ['mathematics', 'applied science'] ['history']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['physics'] ['african american studies']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['statistics and data science'] ['statistics and data science']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['atmospheric and oceanic sciences']
# ['applied mathematics'] ['business economics']
# ['applied mathematics'] ['computer science']
# ['applied mathematics'] ['economics']
# ['applied mathematics'] ['financial actuarial mathematics']
# ['applied mathematics'] ['global studies']
# ['applied mathematics'] ['human biology and society - ba']
# ['applied mathematics'] ['mathematics']
# ['applied mathematics'] ['mathematics of computation']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['microbiology, immunology, and molecular genetics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['political science']
# ['applied mathematics'] ['psychobiology']
# ['applied mathematics'] ['sociology']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['economics']
# ['astrophysics'] ['physics']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['atmospheric and oceanic sciences'] ['economics']
# ['atmospheric and oceanic sciences'] ['geography', 'environmental studies']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['aerospace engineering']
# ['biochemistry'] ['anthropology']
# ['biochemistry'] ['anthropology-bs']
# ['biochemistry'] ['applied linguistics']
# ['biochemistry'] ['applied mathematics']
# ['biochemistry'] ['asian american studies']
# ['biochemistry'] ['asian humanities']
# ['biochemistry'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['atmospheric and oceanic sciences', 'mathematics']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['bioengineering']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['biophysics']
# ['biochemistry'] ['business economics']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['chemistry', 'materials science']
# ['biochemistry'] ['communication']
# ['biochemistry'] ['economics']
# ['biochemistry'] ['english']
# ['biochemistry'] ['environmental science']
# ['biochemistry'] ['european languages and transcultural studies with french and francophone']
# ['biochemistry'] ['gender studies']
# ['biochemistry'] ['geography']
# ['biochemistry'] ['geography', 'environmental studies']
# ['biochemistry'] ['history']
# ['biochemistry'] ['human biology and society - bs']
# ['biochemistry'] ['international development studies']
# ['biochemistry'] ['italian and special fields']
# ['biochemistry'] ['japanese']
# ['biochemistry'] ['linguistics']
# ['biochemistry'] ['marine biology']
# ['biochemistry'] ['microbiology, immunology, and molecular genetics']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['music']
# ['biochemistry'] ['neuroscience']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['physics']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['political science']
# ['biochemistry'] ['psychobiology']
# ['biochemistry'] ['psychology']
# ['biochemistry'] ['sociology']
# ['biochemistry'] ['theater']
# ['biophysics'] ['biochemistry']
# ['biophysics'] ['biophysics']
# ['biophysics'] ['computer science']
# ['biophysics'] ['economics']
# ['biophysics'] ['environmental science']
# ['biophysics'] ['history']
# ['biophysics'] ['neuroscience']
# ['biophysics'] ['physics']
# ['biophysics'] ['physiological science']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['applied mathematics']
# ['chemistry'] ['asian american studies']
# ['chemistry'] ['asian humanities']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['biology']
# ['chemistry'] ['business economics']
# ['chemistry'] ['chemical engineering']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['chemistry', 'materials science']
# ['chemistry'] ['classical civilization']
# ['chemistry'] ['cognitive science']
# ['chemistry'] ['communication']
# ['chemistry'] ['computational and systems biology']
# ['chemistry'] ['economics']
# ['chemistry'] ['environmental science']
# ['chemistry'] ['general chemistry']
# ['chemistry'] ['geography', 'environmental studies']
# ['chemistry'] ['human biology and society - ba']
# ['chemistry'] ['japanese']
# ['chemistry'] ['korean']
# ['chemistry'] ['linguistics']
# ['chemistry'] ['linguistics and psychology']
# ['chemistry'] ['materials engineering']
# ['chemistry'] ['microbiology, immunology, and molecular genetics']
# ['chemistry'] ['molecular, cell, and developmental biology']
# ['chemistry'] ['neuroscience']
# ['chemistry'] ['no degree']
# ['chemistry'] ['physics']
# ['chemistry'] ['political science']
# ['chemistry'] ['psychobiology']
# ['chemistry'] ['psychology']
# ['chemistry'] ['sociology']
# ['chemistry'] ['statistics and data science']
# ['chemistry', 'materials science'] ['chemistry']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['chemistry', 'materials science'] ['computer science']
# ['chemistry', 'materials science'] ['environmental science']
# ['chemistry', 'materials science'] ['materials engineering']
# ['earth and environmental science'] ['economics']
# ['earth and environmental science'] ['environmental science']
# ['chemistry'] ['no degree']
# ['geology', 'engineering geology'] ['geophysics', 'applied geophysics']
# ['geology', 'engineering geology'] ['history']
# ['geology', 'paleobiology'] ['anthropology']
# ['geology', 'paleobiology'] ['geology', 'paleobiology']
# ['geophysics', 'applied geophysics'] ['geology']
# ['geophysics', 'applied geophysics'] ['no degree']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['asian american studies']
# ['mathematics'] ['asian humanities']
# ['mathematics'] ['atmospheric and oceanic sciences']
# ['mathematics'] ['chemical engineering']
# ['mathematics'] ['chicana and chicano studies']
# ['mathematics'] ['economics']
# ['mathematics'] ['electrical engineering']
# ['mathematics'] ['english']
# ['mathematics'] ['financial actuarial mathematics']
# ['mathematics'] ['geography']
# ['mathematics'] ['japanese']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'applied science']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['no degree']
# ['mathematics'] ['political science']
# ['mathematics'] ['psychobiology']
# ['mathematics'] ['psychology']
# ['mathematics'] ['sociology']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['economics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['mathematics', 'applied science']
# ['mathematics for teaching'] ['no degree']
# ['mathematics for teaching'] ['psychology']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['asian american studies']
# ['mathematics of computation'] ['cognitive science']
# ['mathematics of computation'] ['computer science']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics', 'applied science'] ['anthropology']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['astrophysics']
# ['mathematics', 'applied science'] ['biology']
# ['mathematics', 'applied science'] ['business economics']
# ['mathematics', 'applied science'] ['cognitive science']
# ['mathematics', 'applied science'] ['communication']
# ['mathematics', 'applied science'] ['economics']
# ['mathematics', 'applied science'] ['electrical engineering']
# ['mathematics', 'applied science'] ['environmental science']
# ['mathematics', 'applied science'] ['financial actuarial mathematics']
# ['mathematics', 'applied science'] ['geography', 'environmental studies']
# ['mathematics', 'applied science'] ['human biology and society - ba']
# ['mathematics', 'applied science'] ['linguistics and asian languages and cultures']
# ['mathematics', 'applied science'] ['linguistics and computer science']
# ['mathematics', 'applied science'] ['mathematics']
# ['mathematics', 'applied science'] ['mathematics of computation']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['mathematics', 'economics']
# ['mathematics', 'applied science'] ['molecular, cell, and developmental biology']
# ['mathematics', 'applied science'] ['neuroscience']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'applied science'] ['physics']
# ['mathematics', 'applied science'] ['political science']
# ['mathematics', 'applied science'] ['psychobiology']
# ['mathematics', 'applied science'] ['psychology']
# ['mathematics', 'applied science'] ['statistics and data science']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['business economics']
# ['mathematics', 'economics'] ['communication']
# ['mathematics', 'economics'] ['computer science and engineering']
# ['mathematics', 'economics'] ['economics']
# ['mathematics', 'economics'] ['environmental science']
# ['mathematics', 'economics'] ['financial actuarial mathematics']
# ['mathematics', 'economics'] ['history']
# ['mathematics', 'economics'] ['linguistics and psychology']
# ['mathematics', 'economics'] ['mathematics']
# ['mathematics', 'economics'] ['mathematics of computation']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['philosophy']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['aerospace engineering']
# ['physics'] ['applied mathematics']
# ['physics'] ['biochemistry']
# ['physics'] ['business economics']
# ['physics'] ['cognitive science']
# ['physics'] ['computer science']
# ['physics'] ['economics']
# ['physics'] ['electrical engineering']
# ['physics'] ['environmental science']
# ['physics'] ['geography']
# ['physics'] ['geophysics', 'geophysics and space physics']
# ['physics'] ['history']
# ['physics'] ['linguistics and computer science']
# ['physics'] ['mathematics']
# ['physics'] ['mathematics of computation']
# ['physics'] ['mechanical engineering']
# ['physics'] ['microbiology, immunology, and molecular genetics']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['physics'] ['physics-ba']
# ['physics'] ['political science']
# ['physics'] ['sociology']
# ['statistics and data science'] ['applied mathematics']
# ['statistics and data science'] ['asian american studies']
# ['statistics and data science'] ['linguistics']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['anthropology']
# ['undeclared'] ['applied linguistics']
# ['undeclared'] ['applied mathematics']
# ['undeclared'] ['architectural studies']
# ['undeclared'] ['art history']
# ['undeclared'] ['asian humanities']
# ['undeclared'] ['atmospheric and oceanic sciences']
# ['undeclared'] ['biochemistry']
# ['undeclared'] ['biology']
# ['undeclared'] ['biophysics']
# ['undeclared'] ['business economics']
# ['undeclared'] ['chemistry']
# ['undeclared'] ['chemistry', 'materials science']
# ['undeclared'] ['cognitive science']
# ['undeclared'] ['computer science']
# ['undeclared'] ['economics']
# ['undeclared'] ['electrical engineering']
# ['undeclared'] ['environmental science']
# ['undeclared'] ['financial actuarial mathematics']
# ['undeclared'] ['geography']
# ['undeclared'] ['geography', 'environmental studies']
# ['undeclared'] ['geophysics', 'applied geophysics']
# ['undeclared'] ['history']
# ['undeclared'] ['international development studies']
# ['undeclared'] ['linguistics and psychology']
# ['undeclared'] ['mathematics']
# ['undeclared'] ['mathematics of computation']
# ['undeclared'] ['mathematics', 'economics']
# ['undeclared'] ['microbiology, immunology, and molecular genetics']
# ['undeclared'] ['molecular, cell, and developmental biology']
# ['undeclared'] ['no degree']
# ['undeclared'] ['philosophy']
# ['undeclared'] ['physics']
# ['undeclared'] ['physiological science']
# ['undeclared'] ['political science']
# ['undeclared'] ['psychobiology']
# ['undeclared'] ['psychology']
# ['undeclared'] ['sociology']
# ['undeclared'] ['statistics and data science']
# ['undeclared'] ['study of religion']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['astrophysics']
# ['applied mathematics'] ['atmospheric and oceanic sciences']
# ['applied mathematics'] ['atmospheric and oceanic sciences', 'mathematics']
# ['applied mathematics'] ['gender studies']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['physics']
# ['applied mathematics'] ['physics-ba']
# ['astrophysics'] ['anthropology']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['philosophy']
# ['astrophysics'] ['physics']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['chemical engineering']
# ['biochemistry'] ['chemistry']
# ['biochemistry'] ['ecology, behavior, and evolution']
# ['biochemistry'] ['general chemistry']
# ['biochemistry'] ['japanese']
# ['biochemistry'] ['microbiology, immunology, and molecular genetics']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['physics-ba']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['psychobiology']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['asian humanities']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['biology']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['chemistry', 'materials science']
# ['chemistry'] ['english']
# ['chemistry'] ['environmental science']
# ['chemistry'] ['geography']
# ['chemistry'] ['geography', 'environmental studies']
# ['chemistry'] ['linguistics and asian languages and cultures']
# ['chemistry'] ['mathematics', 'economics']
# ['chemistry'] ['no degree']
# ['chemistry'] ['sociology']
# ['chemistry'] ['statistics and data science']
# ['chemistry'] ['study of religion']
# ['chemistry', 'materials science'] ['biochemistry']
# ['chemistry', 'materials science'] ['chemistry']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['earth and environmental science'] ['earth and environmental science']
# ['geology', 'engineering geology'] ['geology', 'engineering geology']
# ['mathematics'] ['african american studies']
# ['mathematics'] ['anthropology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['atmospheric and oceanic sciences']
# ['mathematics'] ['biochemistry']
# ['mathematics'] ['economics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'applied science']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['no degree']
# ['mathematics'] ['philosophy']
# ['mathematics'] ['physics']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['mathematics', 'applied science']
# ['mathematics for teaching'] ['statistics and data science']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['geography']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['asian humanities']
# ['mathematics', 'applied science'] ['biochemistry']
# ['mathematics', 'applied science'] ['geography']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['mathematics', 'economics']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'applied science'] ['statistics and data science']
# ['mathematics', 'economics'] ['anthropology']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['asian humanities']
# ['mathematics', 'economics'] ['gender studies']
# ['mathematics', 'economics'] ['geography']
# ['mathematics', 'economics'] ['geography', 'environmental studies']
# ['mathematics', 'economics'] ['history']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['philosophy']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['anthropology']
# ['physics'] ['applied mathematics']
# ['physics'] ['astrophysics']
# ['physics'] ['biophysics']
# ['physics'] ['chemistry', 'materials science']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['statistics and data science'] ['applied mathematics']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['geology']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['international development studies']
# ['applied mathematics'] ['mathematics']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['sociology']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['applied mathematics']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['central and east european languages and cultures']
# ['astrophysics'] ['english']
# ['astrophysics'] ['environmental science']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['anthropology']
# ['biochemistry'] ['anthropology-bs']
# ['biochemistry'] ['astrophysics']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['chicana and chicano studies']
# ['biochemistry'] ['european languages and transcultural studies with french and francophone']
# ['biochemistry'] ['gender studies']
# ['biochemistry'] ['history']
# ['biochemistry'] ['human biology and society - bs']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['political science']
# ['biochemistry'] ['psychobiology']
# ['biochemistry'] ['psychology']
# ['biochemistry'] ['sociology']
# ['biochemistry'] ['spanish']
# ['biochemistry'] ['spanish and community and culture']
# ['biochemistry'] ['spanish and portuguese']
# ['biophysics'] ['biology']
# ['biophysics'] ['classical civilization']
# ['biophysics'] ['physics']
# ['chemistry'] ['anthropology']
# ['chemistry'] ['applied mathematics']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['history']
# ['chemistry'] ['human biology and society - ba']
# ['chemistry'] ['international development studies']
# ['chemistry'] ['linguistics and psychology']
# ['chemistry'] ['mathematics']
# ['chemistry'] ['no degree']
# ['chemistry'] ['physics-ba']
# ['chemistry'] ['political science']
# ['chemistry'] ['psychobiology']
# ['chemistry'] ['sociology']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['chemistry'] ['political science']
# ['geology'] ['geography', 'environmental studies']
# ['geophysics', 'applied geophysics'] ['world arts and cultures']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['atmospheric and oceanic sciences']
# ['mathematics'] ['biology']
# ['mathematics'] ['chicana and chicano studies']
# ['mathematics'] ['economics']
# ['mathematics'] ['english']
# ['mathematics'] ['environmental science']
# ['mathematics'] ['international development studies']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['no degree']
# ['mathematics'] ['political science']
# ['mathematics'] ['psychology']
# ['mathematics'] ['sociology']
# ['mathematics'] ['spanish and community and culture']
# ['mathematics for teaching'] ['gender studies']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['biology']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'applied science'] ['political science']
# ['mathematics', 'applied science'] ['psychology']
# ['mathematics', 'applied science'] ['sociology']
# ['mathematics', 'economics'] ['business economics']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['political science']
# ['mathematics', 'economics'] ['sociology']
# ['mathematics', 'economics'] ['spanish']
# ['physics'] ['biology']
# ['physics'] ['biophysics']
# ['physics'] ['earth and environmental science']
# ['physics'] ['ethnomusicology']
# ['physics'] ['geology']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['statistics and data science'] ['statistics and data science']
# ['undeclared'] ['anthropology']
# ['undeclared'] ['applied mathematics']
# ['undeclared'] ['biology']
# ['undeclared'] ['chicana and chicano studies']
# ['undeclared'] ['communication']
# ['undeclared'] ['earth and environmental science']
# ['undeclared'] ['economics']
# ['undeclared'] ['english']
# ['undeclared'] ['film and television']
# ['undeclared'] ['gender studies']
# ['undeclared'] ['geography']
# ['undeclared'] ['geology', 'engineering geology']
# ['undeclared'] ['history']
# ['undeclared'] ['no degree']
# ['undeclared'] ['physics']
# ['undeclared'] ['political science']
# ['undeclared'] ['psychobiology']
# ['undeclared'] ['psychology']
# ['undeclared'] ['sociology']
# ['undeclared'] ['spanish']
# ['undeclared'] ['spanish and community and culture']
# ['undeclared'] ['statistics and data science']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['astrophysics']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['molecular, cell, and developmental biology']
# ['chemistry'] ['no degree']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['no degree']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['anthropology']
# ['mathematics', 'economics'] ['geography']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['physics'] ['atmospheric and oceanic sciences']
# ['physics'] ['biophysics']
# ['physics'] ['physics']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['architectural studies']
# ['applied mathematics'] ['asian studies']
# ['applied mathematics'] ['atmospheric and oceanic sciences']
# ['applied mathematics'] ['biochemistry']
# ['applied mathematics'] ['bioengineering']
# ['applied mathematics'] ['biology']
# ['applied mathematics'] ['business economics']
# ['applied mathematics'] ['chemical engineering']
# ['applied mathematics'] ['chemistry', 'materials science']
# ['applied mathematics'] ['cognitive science']
# ['applied mathematics'] ['computer science']
# ['applied mathematics'] ['computer science and engineering']
# ['applied mathematics'] ['economics']
# ['applied mathematics'] ['electrical engineering']
# ['applied mathematics'] ['english']
# ['applied mathematics'] ['financial actuarial mathematics']
# ['applied mathematics'] ['jewish studies']
# ['applied mathematics'] ['mathematics']
# ['applied mathematics'] ['mathematics of computation']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['sociology']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['biophysics']
# ['astrophysics'] ['design ', ' media arts']
# ['astrophysics'] ['electrical engineering']
# ['astrophysics'] ['financial actuarial mathematics']
# ['astrophysics'] ['mathematics']
# ['astrophysics'] ['mathematics of computation']
# ['astrophysics'] ['no degree']
# ['astrophysics'] ['physics']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['atmospheric and oceanic sciences'] ['environmental science']
# ['biochemistry'] ['anthropology']
# ['biochemistry'] ['anthropology-bs']
# ['biochemistry'] ['applied linguistics']
# ['biochemistry'] ['applied mathematics']
# ['biochemistry'] ['asian american studies']
# ['biochemistry'] ['asian humanities']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['biology']
# ['biochemistry'] ['biophysics']
# ['biochemistry'] ['business economics']
# ['biochemistry'] ['chemical engineering']
# ['biochemistry'] ['chemistry', 'materials science']
# ['biochemistry'] ['computational and systems biology']
# ['biochemistry'] ['computer science']
# ['biochemistry'] ['economics']
# ['biochemistry'] ['geology']
# ['biochemistry'] ['history']
# ['biochemistry'] ['human biology and society - bs']
# ['biochemistry'] ['marine biology']
# ['biochemistry'] ['mathematics of computation']
# ['biochemistry'] ['mechanical engineering']
# ['biochemistry'] ['microbiology, immunology, and molecular genetics']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['neuroscience']
# ['biochemistry'] ['no degree']
# ['biochemistry'] ['physiological science']
# ['biochemistry'] ['political science']
# ['biochemistry'] ['psychobiology']
# ['biochemistry'] ['psychology']
# ['biochemistry'] ['sociology']
# ['biochemistry'] ['statistics and data science']
# ['biophysics'] ['applied mathematics']
# ['biophysics'] ['biology']
# ['biophysics'] ['biophysics']
# ['chemistry'] ['arabic']
# ['chemistry'] ['art']
# ['chemistry'] ['atmospheric and oceanic sciences']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['biology']
# ['chemistry'] ['business economics']
# ['chemistry'] ['chemical engineering']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['chemistry', 'materials science']
# ['chemistry'] ['economics']
# ['chemistry'] ['english']
# ['chemistry'] ['environmental science']
# ['chemistry'] ['film and television']
# ['chemistry'] ['history']
# ['chemistry'] ['linguistics and computer science']
# ['chemistry'] ['materials engineering']
# ['chemistry'] ['mathematics', 'economics']
# ['chemistry'] ['mechanical engineering']
# ['chemistry'] ['microbiology, immunology, and molecular genetics']
# ['chemistry'] ['neuroscience']
# ['chemistry'] ['no degree']
# ['chemistry'] ['political science']
# ['chemistry'] ['psychobiology']
# ['chemistry'] ['psychology']
# ['chemistry'] ['sociology']
# ['chemistry', 'materials science'] ['applied mathematics']
# ['chemistry', 'materials science'] ['architectural studies']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['chemistry', 'materials science'] ['computer science']
# ['chemistry', 'materials science'] ['economics']
# ['chemistry', 'materials science'] ['electrical engineering']
# ['chemistry', 'materials science'] ['english']
# ['chemistry', 'materials science'] ['linguistics and psychology']
# ['chemistry', 'materials science'] ['mathematics', 'economics']
# ['chemistry', 'materials science'] ['statistics and data science']
# ['earth and environmental science'] ['economics']
# ['earth and environmental science'] ['english']
# ['earth and environmental science'] ['environmental science']
# ['earth and environmental science'] ['no degree']
# ['geology'] ['art history']
# ['geology'] ['environmental science']
# ['geology', 'engineering geology'] ['geology', 'engineering geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['art history']
# ['mathematics'] ['atmospheric and oceanic sciences', 'mathematics']
# ['mathematics'] ['business economics']
# ['mathematics'] ['classical civilization']
# ['mathematics'] ['cognitive science']
# ['mathematics'] ['computer science']
# ['mathematics'] ['economics']
# ['mathematics'] ['electrical engineering']
# ['mathematics'] ['financial actuarial mathematics']
# ['mathematics'] ['geophysics', 'applied geophysics']
# ['mathematics'] ['history']
# ['mathematics'] ['italian and special fields']
# ['mathematics'] ['linguistics']
# ['mathematics'] ['linguistics and asian languages and cultures']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['mechanical engineering']
# ['mathematics'] ['middle eastern studies']
# ['mathematics'] ['no degree']
# ['mathematics'] ['physics']
# ['mathematics'] ['political science']
# ['mathematics'] ['psychobiology']
# ['mathematics'] ['psychology']
# ['mathematics'] ['sociology']
# ['mathematics for teaching'] ['anthropology']
# ['mathematics for teaching'] ['history']
# ['mathematics for teaching'] ['mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['psychology']
# ['mathematics for teaching'] ['sociology']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics', 'applied science'] ['anthropology']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['atmospheric and oceanic sciences', 'mathematics']
# ['mathematics', 'applied science'] ['biochemistry']
# ['mathematics', 'applied science'] ['biology']
# ['mathematics', 'applied science'] ['business economics']
# ['mathematics', 'applied science'] ['chinese']
# ['mathematics', 'applied science'] ['computer science']
# ['mathematics', 'applied science'] ['economics']
# ['mathematics', 'applied science'] ['financial actuarial mathematics']
# ['mathematics', 'applied science'] ['linguistics']
# ['mathematics', 'applied science'] ['mathematics']
# ['mathematics', 'applied science'] ['mathematics of computation']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ...
# ['financial actuarial mathematics'] ['mathematics']
# ['financial actuarial mathematics'] ['mathematics', 'economics']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['financial actuarial mathematics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'economics']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['applied mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['data theory']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['cognitive science']
# ['mathematics', 'economics'] ['economics']
# ['mathematics', 'economics'] ['european languages and transcultural studies with german']
# ['mathematics', 'economics'] ['financial actuarial mathematics']
# ['mathematics', 'economics'] ['mathematics']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['applied mathematics']
# ['physics'] ['mathematics', 'applied science']
# ['physics'] ['mathematics', 'economics']
# ['physics'] ['physics']
# ['physics'] ['physics-ba']
# ['statistics and data science'] ['applied mathematics']
# ['statistics and data science'] ['data theory']
# ['statistics and data science'] ['economics']
# ['statistics and data science'] ['geography']
# ['statistics and data science'] ['mathematics']
# ['statistics and data science'] ['no degree']
# ['statistics and data science'] ['statistics and data science']
# ['applied mathematics'] ['economics']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry'] ['psychology']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['undeclared'] ['psychology']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['education and social transformation']
# ['applied mathematics'] ['mathematics']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['no degree']
# ['astrophysics'] ['physics']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['no degree']
# ['data theory'] ['history']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['geology']
# ['engineering geology'] ['geology']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['geology']
# ['geophysics'] ['geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics for teaching']
# ['mathematics'] ['no degree']
# ['mathematics'] ['physics']
# ['mathematics for teaching'] ['applied mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['statistics and data science']
# ['mathematics', 'economics'] ['physics']
# ['physics'] ['physics']
# ['statistics and data science'] ['no degree']
# ['statistics and data science'] ['statistics and data science']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['atmospheric and oceanic sciences', 'mathematics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['geophysics'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['asian american studies']
# ['applied mathematics'] ['comparative literature']
# ['applied mathematics'] ['financial actuarial mathematics']
# ['applied mathematics'] ['mathematics']
# ['applied mathematics'] ['mathematics of computation']
# ['applied mathematics'] ['mathematics', 'economics']
# ['applied mathematics'] ['no degree']
# ['applied mathematics'] ['statistics and data science']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['atmospheric and oceanic sciences']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['general chemistry']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['chemistry', 'materials science']
# ['data theory'] ['applied mathematics']
# ['data theory'] ['data theory']
# ['data theory'] ['mathematics of computation']
# ['data theory'] ['no degree']
# ['data theory'] ['statistics and data science']
# ['earth and environmental science'] ['earth and environmental science']
# ['earth and environmental science'] ['geography', 'environmental studies']
# ['earth and environmental science'] ['no degree']
# ['financial actuarial mathematics'] ['financial actuarial mathematics']
# ['financial actuarial mathematics'] ['mathematics of computation']
# ['financial actuarial mathematics'] ['mathematics', 'economics']
# ['financial actuarial mathematics'] ['no degree']
# ['financial actuarial mathematics'] ['statistics and data science']
# ['geology'] ['geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['economics']
# ['mathematics'] ['financial actuarial mathematics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['mathematics of computation']
# ['mathematics'] ['mathematics', 'applied science']
# ['mathematics'] ['no degree']
# ['mathematics'] ['statistics and data science']
# ['mathematics for teaching'] ['applied mathematics']
# ['mathematics for teaching'] ['mathematics for teaching']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['applied mathematics']
# ['mathematics of computation'] ['mathematics of computation']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['applied mathematics']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['applied mathematics']
# ['mathematics', 'economics'] ['data theory']
# ['mathematics', 'economics'] ['financial actuarial mathematics']
# ['mathematics', 'economics'] ['mathematics']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['mathematics', 'economics'] ['statistics and data science']
# ['physics'] ['mathematics']
# ['physics'] ['mathematics of computation']
# ['physics'] ['no degree']
# ['physics'] ['philosophy']
# ['physics'] ['physics']
# ['physics'] ['sociology']
# ['statistics and data science'] ['applied mathematics']
# ['statistics and data science'] ['cognitive science']
# ['statistics and data science'] ['linguistics and computer science']
# ['statistics and data science'] ['mathematics of computation']
# ['statistics and data science'] ['no degree']
# ['statistics and data science'] ['sociology']
# ['statistics and data science'] ['statistics and data science']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['applied mathematics']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['astrophysics']
# ['astrophysics'] ['no degree']
# ['biochemistry'] ['biochemistry']
# ['biochemistry'] ['molecular, cell, and developmental biology']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['biochemistry']
# ['chemistry'] ['chemistry']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['chemistry']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['geology']
# ['mathematics'] ['applied mathematics']
# ['mathematics'] ['financial actuarial mathematics']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics', 'applied science'] ['mathematics', 'applied science']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['physics'] ['astrophysics']
# ['physics'] ['no degree']
# ['physics'] ['physics']
# ['physics'] ['statistics and data science']
# ['statistics and data science'] ['no degree']
# ['statistics and data science'] ['statistics and data science']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['atmospheric and oceanic sciences', 'mathematics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['atmospheric and oceanic sciences', 'mathematics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['mathematics', 'economics']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['geophysics'] ['no degree']
# ['mathematics'] ['mathematics']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['atmospheric and oceanic sciences', 'mathematics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['climate science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['no degree']
# ['chemistry', 'materials science'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['no degree']
# ['biophysics'] ['no degree']
# ['chemistry'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']
# ['undeclared'] ['no degree']
# ['applied mathematics'] ['no degree']
# ['astrophysics'] ['no degree']
# ['atmospheric and oceanic sciences'] ['no degree']
# ['biochemistry'] ['no degree']
# ['chemistry'] ['no degree']
# ['data theory'] ['no degree']
# ['earth and environmental science'] ['no degree']
# ['engineering geology'] ['no degree']
# ['financial actuarial mathematics'] ['no degree']
# ['geology'] ['no degree']
# ['mathematics'] ['no degree']
# ['mathematics for teaching'] ['no degree']
# ['mathematics of computation'] ['no degree']
# ['mathematics', 'applied science'] ['no degree']
# ['mathematics', 'economics'] ['no degree']
# ['physics'] ['no degree']
# ['statistics and data science'] ['no degree']

# %%
# df[(df.start_dept == 'math') & (df.cohort >= 2010) & (df.cohort <= 2020)]['headcount'].sum()
# df.start_maj.value_counts()

# df[df['start_maj'].str.contains('/') & 
#    (df['start_maj'].str.split('/').str[0].map(maj2dept) == 'math') | 
#    (df['start_maj'].str.split('/').str[1].map(maj2dept) == 'math')]['start_maj'].value_counts()
# math_dbl_majs = ["mathematics/economics", "mathematics/applied science", "atmospheric and oceanic sciences/mathematics"]
# df3 = df[(df.cohort >= 2010) & (df.cohort <= 2020)]
# df3[df3['end_maj'].isin(math_dbl_majs)]

df.end_maj.value_counts()
# Out:
# end_maj
# no degree                                 772
# mathematics                               498
# economics                                 425
# applied mathematics                       341
# statistics and data science               258
#                                          ...
# linguistics and scandinavian languages      1
# linguistics and italian                     1
# portuguese and brazilian studies            1
# individual field of concentration           1
# greek and latin                             1
# Name: count, Length: 124, dtype: int64

# %%
import plotly.graph_objects as go
from ipywidgets import interact, Dropdown, fixed
import pandas as pd

def create_outcome_plot(df, department, urm_status, student_type):
    """
    Create stacked area chart based on filters
    """
    # Create outcome column
    def categorize_outcome(row):
        if row['end_dept'] == 'no degree':
            return 'No Degree'
        elif row['start_dept'] == row['end_dept']:
            return 'Stayed in Department'
        else:
            return 'Other Department'
    
    df['outcome'] = df.apply(categorize_outcome, axis=1)
    
    # Filter data
    filtered = df[df['start_dept'] == department].copy()
    
    if urm_status != 'All':
        filtered = filtered[filtered['urm'] == (urm_status == 'URM')]
    
    if student_type != 'All':
        filtered = filtered[filtered['fresh'] == (student_type == 'Freshman')]
    
    # Group and calculate percentages
    grouped = filtered.groupby(['cohort', 'outcome'])['headcount'].sum().reset_index()
    totals = filtered.groupby('cohort')['headcount'].sum().reset_index()
    totals.rename(columns={'headcount': 'total'}, inplace=True)
    
    grouped = grouped.merge(totals, on='cohort')
    grouped['percentage'] = (grouped['headcount'] / grouped['total']) * 100
    
    # Pivot
    pivot = grouped.pivot(index='cohort', columns='outcome', values='percentage').fillna(0)
    
    # Create figure
    fig = go.Figure()
    
    outcomes = ['Stayed in Department', 'Other Department', 'No Degree']
    colors = ['#268bd2', '#859900', '#dc322f']
    
    for i, outcome in enumerate(outcomes):
        if outcome in pivot.columns:
            fig.add_trace(go.Scatter(
                x=pivot.index,
                y=pivot[outcome],
                name=outcome,
                stackgroup='one',
                fillcolor=colors[i],
                line=dict(width=0.5, color=colors[i]),
                hovertemplate='%{y:.1f}%<extra></extra>'
            ))
    
    # Update layout
    title = f'Student Outcomes for {department.title()} Department'
    if urm_status != 'All':
        title += f' ({urm_status})'
    if student_type != 'All':
        title += f' ({student_type})'
    
    fig.update_layout(
        title=title,
        xaxis_title='Cohort Year',
        yaxis_title='Percentage (%)',
        hovermode='x unified',
        height=500,
        yaxis=dict(range=[0, 100]),
        xaxis=dict(tickmode='linear', tick0=2010, dtick=1),
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=-0.2,
            xanchor="center",
            x=0.5
        ),
        shapes=[
            dict(
                type='line',
                x0=2020,
                x1=2020,
                y0=0,
                y1=100,
                line=dict(color='#657b83', width=2, dash='dash'),
                opacity=0.5
            )
        ]
    )
    
    fig.show()

# Create interactive widget
departments = sorted(df['start_dept'].dropna().unique())
departments.remove('undeclared')

interact(
    create_outcome_plot,
    df=fixed(df),
    department=Dropdown(options=departments, value=departments[0], description='Department:'),
    urm_status=Dropdown(options=['All', 'URM', 'Non-URM'], value='All', description='URM Status:'),
    student_type=Dropdown(options=['All', 'Freshman', 'Transfer'], value='All', description='Student Type:')
)
# Out:
# interactive(children=(Dropdown(description='Department:', options=('aos', 'chemistry and biochemistry', 'epss'…
# <function __main__.create_outcome_plot(df, department, urm_status, student_type)>

# %%
import plotly.graph_objects as go
from ipywidgets import interact, Dropdown, fixed
import pandas as pd

def create_retention_plot(df, urm_status, student_type):
    # Filter cohort range
    df_filtered = df[(df['cohort'] >= 2010) & (df['cohort'] <= 2020)].copy()

    # Create outcome column
    def categorize_outcome(row):
        if row['end_dept'] == 'no degree':
            return 'No Degree'
        elif row['start_dept'] == row['end_dept']:
            return 'Stayed in Department'
        else:
            return 'Other Department'

    df_filtered['outcome'] = df_filtered.apply(categorize_outcome, axis=1)

    # Apply URM filter
    if urm_status != 'All':
        df_filtered = df_filtered[df_filtered['urm'] == (urm_status == 'URM')]

    # Apply student type filter
    if student_type != 'All':
        df_filtered = df_filtered[df_filtered['fresh'] == (student_type == 'Freshman')]

    # Calculate retention per department
    retention_rates = []

    departments = sorted(df_filtered['start_dept'].dropna().unique().tolist())
    if 'undeclared' in departments:
        departments.remove('undeclared')

    for dept in departments:
        dept_df = df_filtered[df_filtered['start_dept'] == dept]

        total = dept_df['headcount'].sum()
        retained = dept_df[dept_df['outcome'] == 'Stayed in Department']['headcount'].sum()

        retention_rate = (retained / total * 100) if total > 0 else 0

        retention_rates.append({
            'dept': dept,
            'retention_rate': retention_rate,
            'total': total
        })

    retention_df = pd.DataFrame(retention_rates).dropna()
    retention_df = retention_df.sort_values('retention_rate', ascending=True)

    # Create Plotly figure
    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=retention_df['retention_rate'],
        y=retention_df['dept'],
        orientation='h',
        text=[f"{v:.1f}%" for v in retention_df['retention_rate']],
        textposition='outside',
        marker=dict(color='#2E86AB'),
        hovertemplate=(
            "<b>%{y}</b><br>"
            "Retention: %{x:.1f}%<br>"
            "Total students: %{customdata}<extra></extra>"
        ),
        customdata=retention_df['total']
    ))

    # Dynamic title
    title = "Average Department Retention Rates (2010–2020 Cohorts)"
    if urm_status != 'All':
        title += f" ({urm_status})"
    if student_type != 'All':
        title += f" ({student_type})"

    fig.update_layout(
        title=title,
        xaxis_title='Retention Rate (%)',
        yaxis_title='Department',
        xaxis=dict(range=[0, 100]),
        height=600,
        margin=dict(l=140, r=40, t=80, b=60),
        template='plotly_white'
    )

    fig.show()


# Interactive controls
interact(
    create_retention_plot,
    df=fixed(df),
    urm_status=Dropdown(
        options=['All', 'URM', 'Non-URM'],
        value='All',
        description='URM Status:'
    ),
    student_type=Dropdown(
        options=['All', 'Freshman', 'Transfer'],
        value='All',
        description='Student Type:'
    )
)
# Out:
# interactive(children=(Dropdown(description='URM Status:', options=('All', 'URM', 'Non-URM'), value='All'), Dro…
# <function __main__.create_retention_plot(df, urm_status, student_type)>

# %%
# Define physical sciences departments
phys_sci_depts = {'aos', 'chemistry and biochemistry', 'epss', 
                'institute of environment and sustainability', 'math', 
                'physics and astronomy', 'statistics'}

# Filter for undeclared students
undeclared = df[df['start_dept'] == 'undeclared'].copy()

# Categorize outcomes
def categorize_undeclared_outcome(row):
    if row['end_dept'] == 'no degree':
        return 'No Degree'
    elif row['end_dept'] in phys_sci_depts:
        return 'Stayed in Physical Sciences'
    else:
        return 'Other Degree'

undeclared['outcome'] = undeclared.apply(categorize_undeclared_outcome, axis=1)

# Group and calculate percentages
grouped = undeclared.groupby(['cohort', 'outcome'])['headcount'].sum().reset_index()
totals = undeclared.groupby('cohort')['headcount'].sum().reset_index()
totals.rename(columns={'headcount': 'total'}, inplace=True)

grouped = grouped.merge(totals, on='cohort')
grouped['percentage'] = (grouped['headcount'] / grouped['total']) * 100
pivot = grouped.pivot(index='cohort', columns='outcome', values='percentage').fillna(0)
# print(grouped)
print(pivot)
# Out:
# outcome   No Degree  Other Degree  Stayed in Physical Sciences
# cohort
# 2010       9.302326     70.542636                    20.155039
# 2011       6.432749     65.497076                    28.070175
# 2012      14.465409     63.522013                    22.012579
# 2013       4.724409     70.866142                    24.409449
# 2014      14.000000     61.333333                    24.666667
# 2015      10.989011     64.835165                    24.175824
# 2016       8.270677     65.413534                    26.315789
# 2017       6.185567     74.226804                    19.587629
# 2018      12.328767     58.904110                    28.767123
# 2019      27.142857     55.714286                    17.142857
# 2020      97.222222      2.777778                     0.000000
# 2021     100.000000      0.000000                     0.000000
# 2022     100.000000      0.000000                     0.000000
# 2023     100.000000      0.000000                     0.000000
